# %% [markdown]
# ## EDS 220 Homework 4: False Color
#
# The purpose of this assignment to utilize false color satellite imagery to investigate the extent of wildfires in California in January, 2025.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import rioxarray as rioxr
import netCDF4

# %% [markdown]
# ### Part 2
# Fire perimeter data exploration

# %%
# Create filepath
path = ('data/landsat8-2025-02-23-palisades-eaton.nc')
# Read in file with xarray
fires = xr.open_dataset(path)
# Print bands and dimensions
fires
# Out:
# <xarray.Dataset> Size: 78MB
# Dimensions:      (y: 1418, x: 2742)
# Coordinates:
#   * y            (y) float64 11kB 3.799e+06 3.799e+06 ... 3.757e+06 3.757e+06
#   * x            (x) float64 22kB 3.344e+05 3.344e+05 ... 4.166e+05 4.166e+05
#     time         datetime64[ns] 8B ...
# Data variables:
#     red          (y, x) float32 16MB ...
#     green        (y, x) float32 16MB ...
#     blue         (y, x) float32 16MB ...
#     nir08        (y, x) float32 16MB ...
#     swir22       (y, x) float32 16MB ...
#     spatial_ref  int64 8B ...

# %% [markdown]
# By printing `fires` I was able to access the number of bands, the dimensions, and the CRS. The CRS is EPSG:32611, and it is projected. I'm also able to tell that this data has 5 spectral bands including: red, green, nir08, and swir22. I was also able to see that the units of the CRS are meters, and the resolution is 30x30 meters.
